# %%
import ImtaTURB as imta
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Separación de 20 cm
# plt.vlines(x, ymin, ymax, colors='k', linestyles='dashed', label='Separación de 20 cm')
# Trazo de ejes
fig, ax = plt.subplots(figsize=(10, 3), dpi=600)
# Lineas verticales (Ejes y formas de pilas)
ejes_lw = 0.5
pilas_lw = 2.0
inf_y = 0.08
sup_y = 0.14
plt.vlines(0.000, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto A
plt.vlines(0.335, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto B
plt.vlines(0.400, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Primera pila (Eje)
plt.vlines(0.375, inf_y, sup_y, colors='k', linestyles='solid', linewidth=pilas_lw) # Primera pila (marco)
plt.vlines(0.425, inf_y, sup_y, colors='k', linestyles='solid', linewidth=pilas_lw) # Primera pila (marco)
plt.vlines(0.465, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto C
plt.vlines(0.500, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto P
plt.vlines(0.535, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto D
plt.vlines(0.600, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Primera pila (Eje)
plt.vlines(0.575, inf_y, sup_y, colors='k', linestyles='solid', linewidth=pilas_lw) # Primera pila (marco)
plt.vlines(0.625, inf_y, sup_y, colors='k', linestyles='solid', linewidth=pilas_lw) # Primera pila (marco)
plt.vlines(0.665, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto D
plt.vlines(0.825, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto E
# Líneas horizontales (Ejes de líneas de muestreo)
inf_x = 0.000
sup_x = 0.825
plt.hlines(0.10, inf_x, sup_x, colors='b', linestyles='dotted', linewidth=ejes_lw)
plt.hlines(0.11, inf_x, sup_x, colors='b', linestyles='dotted', linewidth=ejes_lw)
plt.hlines(0.12, inf_x, sup_x, colors='b', linestyles='dotted', linewidth=ejes_lw)
# Sombreado de pilas
#plt.axvspan(xmin, xmax, ymin=0, ymax=1, color='gray', alpha=0.3)
ashurado = 0.3 # Opacidad de sombreado
plt.axvspan(0.375, 0.425, 0.05, 0.95, color='gray', alpha=ashurado) # Primera pila
plt.axvspan(0.575, 0.625, 0.05, 0.95, color='gray', alpha=ashurado) # Segunda pila
# Puntos en el gráfico
color_puntos = 'b'
plt.plot(0.000, 0.10, markersize=5, marker='o', color=color_puntos) # Punto A-1
plt.plot(0.000, 0.11, markersize=5, marker='o', color=color_puntos) # Punto A-2
plt.plot(0.000, 0.12, markersize=5, marker='o', color=color_puntos) # Punto A-2
plt.plot(0.335, 0.10, markersize=5, marker='o', color=color_puntos) # Punto B-1
plt.plot(0.335, 0.11, markersize=5, marker='o', color=color_puntos) # Punto B-2
plt.plot(0.335, 0.12, markersize=5, marker='o', color=color_puntos) # Punto B-3
plt.plot(0.465, 0.10, markersize=5, marker='o', color=color_puntos) # Punto C-1
plt.plot(0.465, 0.11, markersize=5, marker='o', color=color_puntos) # Punto C-2
plt.plot(0.465, 0.12, markersize=5, marker='o', color=color_puntos) # Punto C-3
plt.plot(0.500, 0.10, markersize=5, marker='o', color=color_puntos) # Punto P-1
plt.plot(0.500, 0.11, markersize=5, marker='o', color=color_puntos) # Punto P-2
plt.plot(0.500, 0.12, markersize=5, marker='o', color=color_puntos) # Punto P-3
plt.plot(0.535, 0.10, markersize=5, marker='o', color=color_puntos) # Punto D-1
plt.plot(0.535, 0.11, markersize=5, marker='o', color=color_puntos) # Punto D-2
plt.plot(0.535, 0.12, markersize=5, marker='o', color=color_puntos) # Punto D-3
plt.plot(0.665, 0.10, markersize=5, marker='o', color=color_puntos) # Punto E-1
plt.plot(0.665, 0.11, markersize=5, marker='o', color=color_puntos) # Punto E-2
plt.plot(0.665, 0.12, markersize=5, marker='o', color=color_puntos) # Punto E-3
plt.plot(0.825, 0.10, markersize=5, marker='o', color=color_puntos) # Punto E-1
plt.plot(0.825, 0.11, markersize=5, marker='o', color=color_puntos) # Punto E-2
plt.plot(0.825, 0.12, markersize=5, marker='o', color=color_puntos) # Punto E-3

# %%
# Carga de archivos resumen de espectros
df = pd.read_csv('resumen_espectros_20cm.csv')
# Asignando valores
p_0 = df.loc[df['Probe']==0, ['r11_frec', 'r11_ener','r22_frec', 'r22_ener', 'r33_frec', 'r33_ener']]
print(p_0)
p_3  = df.loc[df['Probe']==3,  ['r11_frec', 'r11_ener','r22_frec', 'r22_ener', 'r33_frec', 'r33_ener']]
print(p_3)
p_6  = df.loc[df['Probe']==6,  ['r11_frec', 'r11_ener','r22_frec', 'r22_ener', 'r33_frec', 'r33_ener']]
p_18 = df.loc[df['Probe']==18, ['r11_frec', 'r11_ener','r22_frec', 'r22_ener', 'r33_frec', 'r33_ener']]
p_9  = df.loc[df['Probe']==9,  ['r11_frec', 'r11_ener','r22_frec', 'r22_ener', 'r33_frec', 'r33_ener']]
p_12 = df.loc[df['Probe']==12, ['r11_frec', 'r11_ener','r22_frec', 'r22_ener', 'r33_frec', 'r33_ener']]
p_15 = df.loc[df['Probe']==15, ['r11_frec', 'r11_ener','r22_frec', 'r22_ener', 'r33_frec', 'r33_ener']]

plt.plot(p_0['r11_frec'],2, 'bo')
plt.plot(p_3['r11_frec'],3, 'ro')
# Out:
#    r11_frec   r11_ener  r22_frec    r22_ener  r33_frec   r33_ener
# 0      0.68  9186000.0      0.68  19172000.0    0.0533  3036400.0
#    r11_frec    r11_ener  r22_frec    r22_ener  r33_frec   r33_ener
# 3    0.0533  14171000.0      0.68  18674000.0    0.0533  2473100.0

# %%
# Separación de 20 cm
# plt.vlines(x, ymin, ymax, colors='k', linestyles='dashed', label='Separación de 20 cm')
# Trazo de ejes
fig, ax = plt.subplots(figsize=(10, 3), dpi=600)
# Lineas verticales (Ejes y formas de pilas)
ejes_lw = 0.5
pilas_lw = 2.0
inf_y = 0.05
sup_y = 1
plt.vlines(0.000, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto A
plt.vlines(0.335, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto B
plt.vlines(0.400, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Primera pila (Eje)
plt.vlines(0.375, inf_y, sup_y, colors='k', linestyles='solid', linewidth=pilas_lw) # Primera pila (marco)
plt.vlines(0.425, inf_y, sup_y, colors='k', linestyles='solid', linewidth=pilas_lw) # Primera pila (marco)
plt.vlines(0.465, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto C
plt.vlines(0.500, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto P
plt.vlines(0.535, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto D
plt.vlines(0.600, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Primera pila (Eje)
plt.vlines(0.575, inf_y, sup_y, colors='k', linestyles='solid', linewidth=pilas_lw) # Primera pila (marco)
plt.vlines(0.625, inf_y, sup_y, colors='k', linestyles='solid', linewidth=pilas_lw) # Primera pila (marco)
plt.vlines(0.665, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto D
plt.vlines(0.825, inf_y, sup_y, colors='k', linestyles='dashed', linewidth=ejes_lw) # Punto E
# Líneas horizontales (Ejes de líneas de muestreo)
inf_x = 0.000
sup_x = 0.825
#plt.hlines(0.10, inf_x, sup_x, colors='b', linestyles='dotted', linewidth=ejes_lw)
# Sombreado de pilas
#plt.axvspan(xmin, xmax, ymin=0, ymax=1, color='gray', alpha=0.3)
ashurado = 0.3 # Opacidad de sombreado
plt.axvspan(0.375, 0.425, 0.05, 0.95, color='gray', alpha=ashurado) # Primera pila
plt.axvspan(0.575, 0.625, 0.05, 0.95, color='gray', alpha=ashurado) # Segunda pila
# Puntos en el gráfico experimentales
color_vectrino = 'b'
#plt.plot(0.000, 0.10, markersize=5, marker='o', color=color_puntos) # Punto A-1
#plt.plot(0.335, 0.10, markersize=5, marker='o', color=color_puntos) # Punto B-1
#plt.plot(0.465, 0.10, markersize=5, marker='o', color=color_puntos) # Punto C-1
#plt.plot(0.500, 0.10, markersize=5, marker='o', color=color_puntos) # Punto P-1
#plt.plot(0.535, 0.10, markersize=5, marker='o', color=color_puntos) # Punto D-1
#plt.plot(0.665, 0.10, markersize=5, marker='o', color=color_puntos) # Punto E-1
#plt.plot(0.825, 0.10, markersize=5, marker='o', color=color_puntos) # Punto E-1
# Puntos en el gráfico numéricos
color_numerico = 'r'
#plt.plot(x[posicion], y[frecuencia])
# [1,1]
plt.plot(0.000, p_0['r11_frec'], markersize=5, marker='.', color='b') # Punto A-1
plt.plot(0.335, p_3['r11_frec'], markersize=5, marker='.', color='b') # Punto B-1
plt.plot(0.465, p_6['r11_frec'], markersize=5, marker='.', color='b') # Punto C-1
plt.plot(0.500, p_18['r11_frec'], markersize=5, marker='.', color='b') # Punto P-1
plt.plot(0.535, p_9['r11_frec'], markersize=5, marker='.', color='b') # Punto D-1
plt.plot(0.665, p_12['r11_frec'], markersize=5, marker='.', color='b') # Punto E-1
plt.plot(0.825, p_15['r11_frec'], markersize=5, marker='.', color='b') # Punto E-1
# [2,2]
plt.plot(0.000, p_0['r22_frec'], markersize=5, marker='.', color='r') # Punto A-1
plt.plot(0.335, p_3['r22_frec'], markersize=5, marker='.', color='r') # Punto B-1
plt.plot(0.465, p_6['r22_frec'], markersize=5, marker='.', color='r') # Punto C-1
plt.plot(0.500, p_18['r22_frec'], markersize=5, marker='.', color='r') # Punto P-1
plt.plot(0.535, p_9['r22_frec'], markersize=5, marker='.', color='r') # Punto D-1
plt.plot(0.665, p_12['r22_frec'], markersize=5, marker='.', color='r') # Punto E-1
plt.plot(0.825, p_15['r22_frec'], markersize=5, marker='.', color='r') # Punto E-1
# [3,3]
plt.plot(0.000, p_0['r33_frec'], markersize=5, marker='.', color='g') # Punto A-1
plt.plot(0.335, p_3['r33_frec'], markersize=5, marker='.', color='g') # Punto B-1
plt.plot(0.465, p_6['r33_frec'], markersize=5, marker='.', color='g') # Punto C-1
plt.plot(0.500, p_18['r33_frec'], markersize=5, marker='.', color='g') # Punto P-1
plt.plot(0.535, p_9['r33_frec'], markersize=5, marker='.', color='g') # Punto D-1
plt.plot(0.665, p_12['r33_frec'], markersize=5, marker='.', color='g') # Punto E-1
plt.plot(0.825, p_15['r33_frec'], markersize=5, marker='.', color='g') # Punto E-1

# %%
plt.plot(0.000, p_0['r11_frec'],
         0.335, p_3['r11_frec'],
         0.465, p_6['r11_frec'],
         0.500, p_18['r11_frec'],
         0.535, p_9['r11_frec'],
         0.665, p_12['r11_frec'],
         0.825, p_15['r11_frec'], markersize=5,linestyle='solid', marker='.', color='b') # Punto E-1
